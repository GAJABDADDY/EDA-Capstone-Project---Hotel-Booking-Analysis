# %% [markdown]
# <a href="https://colab.research.google.com/github/GAJABDADDY/EDA-Capstone-Project---Hotel-Booking-Analysis/blob/main/Ashish's_EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Summary:**
#
#
# This was an unsupervised project provided to me by AlmaBetter. The main objective of this project was to find a solution for high cancellation rates across City and resort Hotels and what factors were contributing to this problem.
#
#  The hotel booking dataset analysis project provides valuable insights for the hotel industry, offering an opportunity for establishments to optimize their operations and improve customer retention. By considering additional factors, hotels can further enhance their strategies to reduce cancellations and increase revenue.
#
# One crucial aspect to focus on is effective customer communication. Implementing proactive measures to engage with guests throughout their booking journey can significantly impact cancellation rates. This can be achieved through personalized communication channels, such as email or SMS, where hotels can provide relevant information, address concerns, and offer assistance. By establishing a strong line of communication, hotels can build trust and rapport with their guests, increasing the likelihood of them following through with their reservations.
#
# Furthermore, incorporating flexible cancellation policies can serve as a powerful tool in reducing cancellations. Customers often face unforeseen circumstances or last-minute changes in plans, leading to cancellations. By offering flexible options, such as free cancellation within a specified timeframe or the ability to modify reservations without penalties, hotels can alleviate customers' concerns and encourage them to retain their bookings. Such policies demonstrate the hotel's understanding of the guests' needs and willingness to accommodate their changing circumstances.
#
# Another area of focus should be leveraging guest feedback and online reviews. Hotels can analyze customer reviews to identify recurring themes related to cancellations and address them proactively. By promptly addressing and resolving issues raised by previous guests, hotels can demonstrate their commitment to customer satisfaction and alleviate concerns for potential future guests. Moreover, actively soliciting feedback from guests during their stay and after checkout can provide hotels with valuable insights for improving their services and reducing the likelihood of cancellations in the future.
#
# Moreover, investing in technology solutions can greatly assist in reducing cancellations. Utilizing advanced data analytics and machine learning algorithms can help hotels predict and identify patterns associated with potential cancellations. By leveraging these insights, hotels can take proactive measures, such as targeted promotions or personalized offers, to incentivize guests to maintain their reservations. Additionally, technology can streamline the booking process, making it more convenient and efficient for guests, which can contribute to higher satisfaction levels and lower cancellation rates.
#
# Furthermore, collaborating with travel agencies, tour operators, or online booking platforms can expand the reach of hotels and attract a wider customer base. By establishing mutually beneficial partnerships, hotels can tap into existing customer networks and benefit from increased exposure. This can result in higher occupancy rates and reduced cancellations, as hotels gain access to a broader pool of potential guests. Collaborations can also lead to joint marketing campaigns or bundled packages, offering added value to customers and increasing the likelihood of securing bookings.
#
# In conclusion, the hotel booking dataset analysis project provides valuable recommendations for hotels to optimize their strategies and reduce cancellations. By enhancing customer communication, offering flexible cancellation policies, addressing guest feedback, leveraging technology solutions, and exploring partnerships, hotels can effectively minimize cancellations and maximize revenue. Embracing these proactive measures will not only enhance the overall guest experience but also contribute to the long-term success and profitability of hotels in a highly competitive industry. By continually evaluating and adapting their strategies based on data-driven insights, hotels can establish themselves as customer-centric establishments that prioritize guest satisfaction and retention.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/GAJABDADDY/EDA-Capstone-Project---Hotel-Booking-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Business Problem Overview:**
#
# In recent years, City Hotel and Resort Hotel have seen high cancellation rates. Each hotel is now dealing with a number of issues as a result, including fewer revenues and less than ideal hotel room use. Consequently, lowering cancellation rates is both hotels' primary goal in order to increase their efficiency in generating revenue, and for us to offer thorough business advice to address this problem. The analysis of hotel booking cancellations as well as other factors that have no bearing on their business and yearly revenue generation are the main topics of this report.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Finding and reducing Hotel Cancellation Rates

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing Libraries:

#Importing NumPy library
import numpy as np

#Importing Pandas library
import pandas as pd

#Importing Matplotlib and Seaborn library
import seaborn as sns
import matplotlib.pyplot as plt

#Importing Google Drive Package from google.colab library
from google.colab import drive #
drive.mount('/content/drive') #mounting google drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

filepath="/content/drive/MyDrive/EDA Capstone Project/Hotel Bookings.csv"
df=pd.read_csv(filepath)   #storing the location in filepath variable and calling it in .read_csv() method

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

df.head() #Shows the first 5 rows of the dataset by default
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail() #Shows the last 5 rows of the dataset by default
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

df.shape
#The first no. represents the rows and the second no. represents the columns.
#Here, it is 119390 rows and 32 columns !!
# Out:
# (119390, 32)

# %%
df.columns #shows all the columns of the dataset
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# From the following dataset information, we can deduce that company is the column with the least amount of non-null values, meaning that this column has the most number of missing values/null values out of all the 32 columns..

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# .describe() method can be used to show the basic calculations like count, standard deviation, etc. applied to the whole dataset therefore describing the dataset.

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 31994

# %% [markdown]
# Showing the count of duplicated values using len() function..

# %%
duplicates = df[df.duplicated()]
print("Duplicates:")
print(duplicates)
# Out:
# Duplicates:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %% [markdown]
# You can see the printed values showcasing the rows with duplicated columns using the .duplicated() method.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# From the above information, we can deduce that out of all the columns, column 'company' has the most number of missing/null values..
# To solve the issue of missing values, we can replace the missing values with 'na' (meaning not available) for easy understanding of the dataset.

# %%
df.fillna('na')
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# Here, the .fillna() method converts all the null values to the specified parameter. This in turn ensures the data is more user-friendly and in a better readable format.

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# In this heatmap, the white lines show the amount of missing values in the dataset.
# Although most of the heatmap is completely black indicating no missing values, column 'agent' and column 'company' is mostly white, and having too many missing values can cause hinderance in the analysis of data..
#
#
# The column 'agent' shows the amount of people who came to book through agents but due to the amount of missing values, it is better if we drop the column..
#
# On the other hand, column 'company' has so many missing values that it is more of a hinderance than a solution..

# %% [markdown]
# Therefore, as a part of Data Cleaning, it is recommended to remove the inconsistencies of a dataset by removing or dropping the columns.
#
# We can drop the following columns by using the drop function.

# %%
df.drop(['agent','company'], axis=1 , inplace=True) #deleting column 'agent' and 'company'

# %% [markdown]
# Also, the analysis of data will be way more accurate and easy if we remove the rows with missing/na values as they may cause inaccurate and inconsistent analysis of data..
#
# Therefore, we are also going to drop all the rows with missing values.

# %%
df.dropna(inplace=True) #deleting all the rows with missing values

# %% [markdown]
# A look at all the columns after performing Data Cleaning:

# %%
df.isnull().sum() #checking the amount of missing values
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# Here, we can see that all columns have value 0 indicating that there are no missing/NA values !!

# %%
df.shape
# Out:
# (118898, 30)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made,
# length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data for user privacy.
#
#
# In recent years, City Hotel and Resort Hotel have seen high cancellation rates. Each hotel is now dealing with a number of issues as a result, including fewer revenues and less than ideal hotel room use.
#
# Our primary goal is to find the factors responsible and give solution to this business problem accordingly to increase the hotel/resort's efficiency in generating revenue.
#
# The analysis of hotel booking cancellations as well as other factors that have no bearing on their business and yearly revenue generation are the main topics of this report.
#
# The dataset contained 119390 rows and 32 columns before our Data Cleaning process. There were many inconsistencies like missing and duplicate values present in the dataset.
#
# We haven't deleted any duplicate values as of now as they can be important for grouping and sorting values in the future, but we have deleted all the columns and rows with missing values for better consistency of the data.
#
# The dataset after performing Data Cleaning consists of 118898 rows and 30 columns respectively..

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns #shows all the columns of the dataset
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe

df.describe() #using .describe() to generate descriptive statistics of a dataset.
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Field**	: Description
#
# **Hotel** : H1= Resort Hotel H2=City Hotel
#
# **is_cancelled** :	If the booking was cancelled(1) or not(0)
#
# **lead_time**	: Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
# **arrival_date_year** :	Year of arrival date
#
# **arrival_date_month** :	Month of arrival date
#
# **arrival_date_week_number** :	Week number for arrival date
#
# **arrival_dat_day**	: Day of arrival date
#
# **stays_in_weekend_nights** :	Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# **stays_in_week_nights**	: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# **adults** :	Number of adults
#
# **children** :	Number of children
#
# **babies**	: Number of babies
#
# **meal**	: Kind of meal opted for
#
# **country**	: Country code
#
# **market_segment** :	Which segment the customer belongs to
#
#
# **Distribution_channel** :	How the customer accessed the stay- corporate booking/Direct/TA.TO
#
# **is_repeated_guest** : 	Guest coming for first time or not
#
# **previous_cancellation** :	Was there a cancellation before
#
# **previous_bookings** :	Count of previous bookings
#
# **reserved_room_type**	: Type of room reserved
#
# **assigned_room_type**	: Type of room assigned
#
# **booking_changes**	: Count of changes made to booking
#
# **deposit_type**	: Deposit type
#
# **agent**	: Booked through agent
#
# **days_in_waiting_list**	: Number of days in waiting list
#
# **adr** : Average Daily Rate
#
# **customer_type**	: Type of customer
#
# **required_car_parking**	: If car parking is required
#
# **total_of_special_req**	: Number of additional special requirements
#
# **reservation_status**	: Reservation of status
#
# **reservation_status_date**	: Date of the specific status

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Checking the number of Unique Values for each variable/column.

for i in df.columns.tolist():
  print("Total number of unique values in column:", i ,"is",df[i].nunique(),".")
# Out:
# Total number of unique values in column: hotel is 2 .
# Total number of unique values in column: is_canceled is 2 .
# Total number of unique values in column: lead_time is 479 .
# Total number of unique values in column: arrival_date_year is 3 .
# Total number of unique values in column: arrival_date_month is 12 .
# Total number of unique values in column: arrival_date_week_number is 53 .
# Total number of unique values in column: arrival_date_day_of_month is 31 .
# Total number of unique values in column: stays_in_weekend_nights is 15 .
# Total number of unique values in column: stays_in_week_nights is 33 .
# Total number of unique values in column: adults is 14 .
# Total number of unique values in column: children is 5 .
# Total number of unique values in column: babies is 5 .
# Total number of unique values in column: meal is 5 .
# Total number of unique values in column: country is 177 .
# Total number of unique values in column: market_segment is 7 .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# **Note:** The above dataset is being analysed on the basis of not having any further outliers and is suited for data analysis.

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# From the above description, we can see some possible outliers, like in the column **babies**, where the max value is **10** but for now, we are treating all these kinds of outliers as exceptions and all analysis has been made on the basis of this assumption.

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ###**Note: Majority of Data Cleaning techniques have already been performed above !!**

# %%
#Dataset Description:
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# We can see that the dataset contains one major outlier in the column 'adr' which cannot be termed as an exception. Therefore, as a part of the Data Cleaning process, we are going to remove it.
#
# **The visualization of this outlier has been shown in the Visualization section using a BoxPlot. (Chart-1)**

# %%
#Changing the threshhold of the max value.

df=df[df['adr']<5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# We can see the max value of **adr** has now become **510** from **5000** !

# %% [markdown]
# We are going to first check the percentage of Reservations and Cancellations.

# %%
#checking the percentage of Reservations and Cancellations.

cancelled_perc = df['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %% [markdown]
# From this, we can see that the total percentage of reservations were 62.86% and the total percentage of cancellations were 37.13% which is high..
#
# The average rate of cancellation should be around 5% and max upto 10%..

# %% [markdown]
# **The visualization of this percentage has been shown in the Visualization section using a Bar Graph. (Chart-2)**

# %% [markdown]
# Next, we will find out the percentage of reservation and cancellation rates by Hotel Type.

# %%
#checking hotel reservation and cancellation percentage grouped by hotel type

cancelled_perc = df.groupby('hotel')['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)
# Out:
# hotel         is_canceled
# City Hotel    0              0.582918
#               1              0.417082
# Resort Hotel  0              0.720250
#               1              0.279750
# Name: is_canceled, dtype: float64

# %% [markdown]
# From this, we can see that the total percentage of reservations were:
#
# City Hotel = 58.29%
#
# Resort Hotel = 72.02%
#
# and the total percentage of cancellations were:
#
# City Hotel: 41.70%
#
# Resort Hotel = 27.97%

# %% [markdown]
# **The visualization of this percentage has been shown in the Visualization section using a Count Plot. (Chart-3)**

# %% [markdown]
# From the bar graph, we can see the percentage of reservations that are canceled and those that are not. It is obvious that there are still a significant number of reservations that have not been canceled. There are still 37% of clients who canceled their reservation, which has a significant impact on the hotels' earnings.

# %%
#checking hotel reservation and cancellation percentage for resort hotel:

resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
#checking hotel reservation and cancellation percentage for city hotel:

city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118897 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118897 non-null  object
#  1   is_canceled                     118897 non-null  int64
#  2   lead_time                       118897 non-null  int64
#  3   arrival_date_year               118897 non-null  int64
#  4   arrival_date_month              118897 non-null  object
#  5   arrival_date_week_number        118897 non-null  int64
#  6   arrival_date_day_of_month       118897 non-null  int64
#  7   stays_in_weekend_nights         118897 non-null  int64
#  8   stays_in_week_nights            118897 non-null  int64
#  9   adults                          118897 non-null  int64
#  10  children                        118897 non-null  float64
#  11  babies                          118897 non-null  int64
# ...

# %% [markdown]
# Before continuing, we can see that column **'reservation_date_status'** contains date for all the reservations but has object datatype.
#
# Therefore as a part of Data transformation, we are to convert this column to datetime datatype.

# %%
#converting datatype from object to datetime:

df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118897 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118897 non-null  object
#  1   is_canceled                     118897 non-null  int64
#  2   lead_time                       118897 non-null  int64
#  3   arrival_date_year               118897 non-null  int64
#  4   arrival_date_month              118897 non-null  object
#  5   arrival_date_week_number        118897 non-null  int64
#  6   arrival_date_day_of_month       118897 non-null  int64
#  7   stays_in_weekend_nights         118897 non-null  int64
#  8   stays_in_week_nights            118897 non-null  int64
#  9   adults                          118897 non-null  int64
#  10  children                        118897 non-null  float64
#  11  babies                          118897 non-null  int64
# ...

# %% [markdown]
# Now, we can see that we have successfulyy converted it to datetime datatype.

# %%
#Finding mean and grouping by date

resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()
print(resort_hotel)
print(city_hotel)
# Out:
#                                 adr
# reservation_status_date
# 2014-11-18                 0.000000
# 2015-01-01                61.966667
# 2015-01-02                 9.633750
# 2015-01-18                 0.000000
# 2015-01-21                37.301209
# ...                             ...
# 2017-09-08               101.012500
# 2017-09-09               147.778333
# 2017-09-10               145.272500
# 2017-09-12               153.570000
# 2017-09-14               105.930000
#
# [913 rows x 1 columns]
#                                 adr
# reservation_status_date
# 2014-10-17                62.800000
# 2015-01-01                62.063158
# 2015-01-20                76.500000
# 2015-01-30                61.400000
# 2015-02-17                76.500000
# ...                             ...
# 2017-09-03               137.172600
# 2017-09-04               116.925385
# 2017-09-05               154.000000
# 2017-09-06                93.293333
# 2017-09-07               159.685000
#
# ...

# %% [markdown]
# **The visualization of this mean has been shown in the Visualization section using a Scatter Plot (Chart-4) and a Line Graph (Chart-5)**

# %% [markdown]
# From the above code, we can come to an conclusion that the average daily rate of City Hotel is less than the average daily rate or adr of Resort Hotel in some days.
#
# This can be on weekends or during holiday season.

# %% [markdown]
# To find out the reservation status per month, we will first create a new column called 'month' which extracts the month from 'reservation_status_date'.

# %%
#creating a new column and storing month value

df['month'] = df['reservation_status_date'].dt.month

# %% [markdown]
# Now that we have extracted the reservation month information, we can create a graph containing information on reservation status per month.

# %% [markdown]
# **The visualization has been shown in the Visualization section using a Count Plot (Chart-6)**

# %% [markdown]
# From the following graph, we can see that the most number of cancellations were performed in the month of January while the least number of cancellations were performed in the month of August denoted by the orange bar.
#
# On the other hand, the most number of reservations were performed in the month of August while the least number of reservations were performed in the month of December and January denoted by the blue bar.

# %% [markdown]
# From the visualization from the graph, we can interpret that the amount of reservations is the maximum when the cancellations are low and
# the number of reservations is the lowest when the cancellations are maximum.

# %% [markdown]
# With this data, we can find out the reason why people preferred to cancel their bookings more..
#
# It can be due to high prices that people preferred to book less or it can also be due to low reservation that people decided to cancel more..

# %% [markdown]
# Now, we can narrow down our analysis and check whether it was due to prices the cancellation was more for each month.
#
# We will now compare Average Daily Rate or ADR with cancellation rate to find out this condition..

# %% [markdown]
# **The visualization has been shown in the Visualization section using a Bar Plot (Chart-7)**

# %% [markdown]
# From the following graph **(Chart-7)**, when we compare it to our previous graph on reservation status i.e **(Chart-6)**, we are able to prove that:
#
#
#
# The most number of cancellations were performed in the month of January in correlation with the highest number of adr per-month suggesting that people tend to cancel their reservations the most when the price is the highest.
#
# This further leads us to accept the fact that due to higher prices, people tend to cancel their reservations in fear of spending more money and thus go on to search for a different hotel.
#
# The same can be said when we compare and see that the least number of cancellations were done in the month of August in correlation with the prices of the hotel being the lowest..

# %% [markdown]
# Now that we have found the factor relating to higher cancellation rates, let's find out the top 10 countries facing this issue.

# %%
cancelled_data = df[df['is_canceled'] == 1]

top_10_country = cancelled_data['country'].value_counts()[:10]

# %% [markdown]
# **The visualization has been shown in the Visualization section using a Pie Chart (Chart-8)**

# %% [markdown]
# From the above pie chart, we can see the top 10 countries with the Highest cancellation rates in case of Hotel Booking.
#
# Portugal has a massive 70%+ hotel cancellation rate which is the highest and not even close to the other countries, becoming more of an exception.
# This data makes our first priority be to change the rates and hotel services in the country of Portugal facing hotel cancellation rates of more than 70% making it an exception and not even remotely close to other countries' cancellation rates.
#
# The hotels situated in Portugal should try to reduce this huge percentage of cancellation rates by offering discounts and free services as a way of promotion so that people reduce the rate of cancellation. **(explained in insights)**

# %% [markdown]
# Now that we have seen which countries have the most cancellation rates, we are going to check the source of reservation for hotels.

# %%
#checking the sources from where the reservations are made

df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %% [markdown]
# From the above code, we can see that most of the reservations are being done through Online travel agents with 56402 bookings followed by offline travel agents with 24159 bookings..

# %%
#checking the sources from where the reservations are made in percentage form

df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %% [markdown]
# From the above code, we can see that most of the reservations are being done through Online travel agents with 47.43% of the bookings bookings followed by offline travel agents with a percentage of 20.31%.

# %%
#checking the percentage of cancellation rates through different sources

cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %% [markdown]
# On comparing both 'df' and 'cancelled_data', we can see that althought the majority of the bookings have been done through Online agents, the cancellation is also almost the same percentage of number of reservations.
#
# This minute difference between hotel reservation and cancellation percentage could be due to several reasons such as false advertisement, false guarantee, etc. **(explained in insights)**

# %% [markdown]
# We will now check whether the average daily rate (adr) is high for cancelled reservations or non-cancelled reservations.

# %%
#checking adr of cancelled hotel reservation
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace = True)
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

#checking adr of non-cancelled hotel reservation
not_cancelled_data = df[df['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

# %% [markdown]
# Although we can see the adr of cancelled and non-cancelled hotel reservation in **(Chart-9)**, the data available is inconsistent and may provide us with inaccurate readings.
# Therefore, to solve this, we will print and analyze the data of only the years 2016-2017 where the data is the most consistent.
# This will help us provide accurate readings.

# %%
#extracting the data from the year 2016 - 2017 only

cancelled_df_adr_sorted = cancelled_df_adr[(cancelled_df_adr['reservation_status_date']> '2016') & (cancelled_df_adr['reservation_status_date']< '2017')]
not_cancelled_df_adr_sorted = not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date']> '2016') & (not_cancelled_df_adr['reservation_status_date']< '2017')]

# %% [markdown]
# Now, we can observe and analyze the data easily because of accurate readings. **(Chart-10)**

# %% [markdown]
# From the following graph, we can see that the cancellation rate increases as the adr increases and decreases when the adr decreases.
#
# Likely, the non-cancellation rate decreases as the adr decreases and vice-versa. Thus, we can deduce from this data analysis that adr is the most influentital factor when it comes to cancellation rates.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1: Boxplot Visualization showing the major outlier in the column 'adr' :

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Chart - 1 visualization code
#As this code is executed in the end of the colab, this plot shows the data after all the data cleaning has been done.
#Please refer to the above image for visual presentation of outlier.
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Boxplot is commonly used and is one of the best ways to show and compare the normal values with an outlier.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# (Refer to the image)
#
# The max value is above '5000' which gives us the idea that it is an outlier leading us to the conclusion to drop/delete the value.

# %% [markdown]
# #### Chart - 2: Bar Graph comparing the percentage of reservations and cancellations.

# %%
# Chart - 2 visualization code
plt.figure(figsize = ( 5, 4))
plt.title('Reservation status count')
plt.bar(['Not canceled','Canceled'], df['is_canceled'].value_counts(normalize=False), edgecolor = 'k', width = 0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar Graph was picked for this specific scenario to visualise and compare the reservation and cancellation rates as it provides a bar indicating the rate for easy understanding.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that the cancellation rates are more than half the reservation rates indicating main problems faced by Hotels for their low-profit or loss scenarios.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight will help us understand the difference between reservation and cancellation rates which will further help us identify the issues causing such high cancellation rates.

# %% [markdown]
# #### Chart - 3: CountPlot showing the reservation status in different hotels

# %%
# Chart - 3 visualization code
plt.figure(figsize = (8, 4))
ax1 = sns.countplot(x = 'hotel', hue = 'is_canceled', data = df, palette = 'Blues')
plt.title('Reservation status in different hotels', size=20)
plt.xlabel('hotel')
plt.ylabel('number of reservations')
plt.legend(['not canceled', 'canceled'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Countplot helps in frequency visualization, pattern recognition and comparison of categories which allows us to visualize the information easily.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this, we can see that the total percentage of reservations were:
#
# City Hotel = 58.29%
#
# Resort Hotel = 72.02%
#
# and the total percentage of cancellations were:
#
# City Hotel: 41.70%
# Resort Hotel = 27.97%
#
# The accompanying bar graph shows the percentage of reservations that are canceled and those that are not. It is obvious that there are still a significant number of reservations that have not been canceled. There are still 37% of clients who canceled their reservation, which has a significant impact on the hotels' earnings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this will further help us identify all the issues with hotel reservation and cancellations !

# %% [markdown]
# #### Chart - 4: ScatterPlot showing the Average Daily Rate in City and Resort Hotel

# %%
# Chart - 4 visualization code
plt.figure(figsize = (20,8))
plt.title('Average Daily Rate in City and Resort Hotel', fontsize = 30)
plt.scatter(resort_hotel.index, resort_hotel['adr'], label = 'Resort Hotel')
plt.scatter(city_hotel.index, city_hotel['adr'], label = 'City Hotel')
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatterplots are effective in visually representing the relationship or patterns between two continuous variables.
# When comparing prices, a scatterplot can show the distribution of prices and provide insights into the relationship between different variables associated with those prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can come to a conclusion from this graph that the average daily rate of City Hotel is less than the average daily rate or adr of Resort Hotel in some days.
#
# This can be on weekends or during holiday season.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can understand better when and by how much City and Resort Hotel's daily rate differs according to different times due to this visualization.

# %% [markdown]
# #### Chart - 5: Line Graph showing the Average Daily Rate in City and Resort Hotel

# %%
# Chart - 5 visualization code

df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)

city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)

resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()


plt.figure(figsize = (20,8))
plt.title('Average Daily Rate in City and Resort Hotel', fontsize = 30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label = 'Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label = 'City Hotel')
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line graph is a suitable choice for comparing prices over time or across different categories. Line graphs are effective at displaying trends and patterns in data, making them particularly useful for visualizing changes in prices over a continuous variable, such as time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can come to a conclusion from this graph that the average daily rate of City Hotel is less than the average daily rate or adr of Resort Hotel in some days.
#
# This can be on weekends or during holiday season.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# We can understand better when and by how much City and Resort Hotel's daily rate differs according to different times due to this visualization.

# %% [markdown]
# #### Chart - 6: CountPlot showing the reservation status per month

# %%
# Chart - 6 visualization code

plt.figure(figsize = (16,8))
ax1 = sns.countplot(x = 'month', hue = 'is_canceled', data = df, palette = 'bright')
plt.title('Reservation status per month', size = 20)
plt.xlabel ('month')
plt.ylabel('number of reservations')
plt.legend(['not canceled', 'canceled'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Countplot helps in frequency visualization, pattern recognition and comparison of categories which allows us to visualize the information easily.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the following graph, we can see that the most number of cancellations were performed in the month of January while the least number of cancellations were performed in the month of August denoted by the orange bar.
#
# On the other hand, the most number of reservations were performed in the month of August while the least number of reservations were performed in the month of December and January denoted by the blue bar.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This following graph will help us to find the main cause behind high cancellation and reservation rates during the year.

# %% [markdown]
# #### Chart - 7: BarPlot showing the ADR per month

# %%
# Chart - 7 visualization code

plt.figure(figsize=(15, 8))
plt.title('ADR per month', fontsize=30)
sns.barplot(x='month', y='adr', data=df[df['is_canceled'] == 1].groupby('month')['adr'].sum().reset_index())
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plot helps in visualization of aggregated data, flexibility of variables and comparison of categories which allows us to visualize the information easily. It is also easy to distinguish because of the multi-colored bars.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the following graph, when we compare it to our previous graph on reservation status, we are able to prove our hypothesis that:
#
# the most number of cancellations were performed in the month of January in correlation with the highest number of adr per-month suggesting that people tend to cancel their reservations the most when the price is the highest.
#
# This further leads us to accept the fact that due to higher prices, people tend to cancel their reservations in fear of spending more money and thus go on to search for a different hotel.
#
# The same can be said when we compare and see that the least number of cancellations were done in the month of August in correlation with the prices of the hotel being the lowest..

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This following graph helped us to prove our hypothesis that people tend to cancel their reservations more when the prices are high.

# %% [markdown]
# #### Chart - 8: Pie Chart showing the Top 10 countries with reservations canceled

# %%
# Chart - 8 visualization code

plt.figure(figsize = (8,8))
plt.title('Top 10 countries with reservation canceled')
plt.pie(top_10_country, autopct = '%.2f', labels = top_10_country.index)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are a suitable choice for visualizing data when it comes to proportions, representing the relative magnitude of each category and because pie charts work best with limited categories, here being only 10 categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see the top 10 countries with the Highest cancellation rates in case of Hotel Booking.
#
# Portugal has a massive 70%+ hotel cancelation rate which is the highest and not even close to the other countries, becoming more of an exception.
# This data makes our first priority be to change the rates and hotel services in the country of Portugal facing hotel cancellation rates of more than 70% making it an exception and not even remotely close to other countries' cancellation rates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This chart helps us to understand better which countries suffer the highest cancellation rates which helps to divert focus on countries that need our attention the most, here the country being Portugal.

# %% [markdown]
# #### Chart - 9: Hotel Cancellation and Non-Cancellation rates in comparison to ADR

# %%
# Chart - 9 visualization code

plt.figure(figsize = (20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label = 'not cancelled')
plt.plot(cancelled_df_adr[ 'reservation_status_date'], cancelled_df_adr['adr'], label = 'cancelled')
plt.legend()

# %% [markdown]
# #### Chart - 10: Hotel Cancellation and Non-Cancellation rates in comparison to ADR (2016-2017)

# %%
# Chart - 10 visualization code

plt.figure(figsize = (20,6))
plt.title('Average Daily Rate', fontsize=30)
plt.plot(not_cancelled_df_adr_sorted['reservation_status_date'], not_cancelled_df_adr_sorted['adr'], label = 'not cancelled')
plt.plot(cancelled_df_adr_sorted[ 'reservation_status_date'], cancelled_df_adr_sorted['adr'], label = 'cancelled')
plt.legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line graph is a suitable choice for comparing prices over time or across different categories. Line graphs are effective at displaying trends and patterns in data, making them particularly useful for visualizing changes in prices over a continuous variable, such as time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the following graph, we can see that the cancellation rate increases as the adr increases and decreases when the adr decreases.
#
# Likely, the non-cancellation rate decreases as the adr decreases and vice-versa.
# Thus, we can deduce from this data analysis that adr is the most influentital factor when it comes to cancellation rates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, as it helps us identify the most crucial factor involved in the increase of reservation and cancellation cases.. i.e the adr.

# %% [markdown]
# #### Chart - 11: Correlation Heatmap of null values in dataset after Data Cleaning

# %%
# Chart - 11 visualization code
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is a visual representation of the correlation matrix, which shows the pairwise correlations between variables in a dataset. It is a useful tool in data analysis and here it shows the absence of null values after Data Cleaning.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here, it shows the absence of null values after Data Cleaning. If there were any null values present, there would have been white lines present in the graph. A completely black correlation heatmap shows tha the dataset is perfect for analysis.

# %% [markdown]
# # **Analysis and Findings:**

# %% [markdown]
# ### **Majority of the analysis has been explained above. This is a short report of the insights found !!**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The accompanying bar graph shows the percentage of reservations that are canceled and those that are not. It is obvious that there are still a significant number of reservations that have not been canceled. There are still 37% of clients who canceled their reservation, which has a significant impact on the hotels' earnings.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In comparison to resort hotels, city hotels have more bookings. It's possible that resort hotels are more expensive than those in cities.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The line graph above shows that, on certain days, the average daily rate for a city hotel is less than that of a resort hotel, and on other days, it is even less. It goes without saying that weekends and holidays may see a rise in resort hotel rates.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We have developed the grouped bar graph to analyze the months with the highest and lowest reservation levels according to reservation status. As can be seen, both the number of confirmed reservations and the number of canceled reservations are largest in the month of August. whereas January is the month with the most canceled reservations.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Possible reasons for high Reservation and Cancellation rates in Hotels:
#
#
#
# 1.   **Flexible Booking Policies:** Many hotels offer flexible booking policies that allow guests to cancel or modify their reservations without incurring significant penalties. This flexibility encourages guests to book reservations even if they are uncertain about their travel plans. As a result, the cancellation rate may be higher because guests have the option to cancel without a significant financial burden.
#
# 2.  **Dynamic Travel Plans:** Travel plans can change for various reasons, including unexpected events, changes in personal circumstances, or last-minute changes in itinerary. These factors contribute to a higher cancellation rate as guests may need to alter or cancel their hotel reservations to accommodate their new plans.
#
# 3.  **Comparison Shopping:** With the advent of online travel agencies and price comparison websites, guests have become more inclined to explore multiple options before finalizing their hotel reservations. This increased comparison shopping can lead to higher cancellation rates as guests may book multiple options and later cancel the ones that no longer meet their preferences or budget.
#
# 4.  **Uncertainty and Risk Aversion:** Some guests may be uncertain about their travel plans due to various factors, such as health concerns, work commitments, or changing travel restrictions. As a result, they may book reservations as a precautionary measure but later cancel if their circumstances change or if they perceive too much risk in proceeding with the trip.
#
# 5.  **Lack of Commitment or Serious Intent:** In certain cases, guests may make reservations without firm intentions of staying at a particular hotel. They might use the reservation as a backup plan while exploring alternative options or simply as a way to keep their options open. Such guests are more likely to cancel their reservations when they find a more suitable or preferred accommodation.

# %% [markdown]
# This bar graph demonstrates that cancellations are most common when prices are
# greatest and are least common when they are lowest. Therefore, the cost of the
# accommodation is solely responsible for the cancellation.
#
# Now, let's see which country has the highest reservation canceled. The top country is Portugal with the highest number of cancellations.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Suggestions to reduce cancellation rates:
#
# 1.   **Clear and Transparent Booking Policies**: Ensure that your booking policies are clearly stated and easily accessible on your website and booking platforms. Provide detailed information about cancellation deadlines, penalties, and any non-refundable charges. Transparent policies help set proper expectations for guests.
#
#
# 2.   **Flexible Cancellation Policies**: Consider offering more flexible cancellation policies, such as free cancellation up to a certain date or a reduced penalty for cancellations made within a specific timeframe. This can make guests feel more comfortable booking with you, knowing they have the option to cancel if needed.
#
# 3.   **Effective Communication**: Establish proactive communication channels with guests. Send confirmation emails immediately after booking, including reservation details and your contact information. Follow up closer to the check-in date to confirm their arrival and provide any additional information they may need. By staying in touch, you can build a relationship and address any concerns that may lead to cancellations.
#
# 4. **Personalized Guest Service**: Provide exceptional customer service throughout the booking process and stay. Train your staff to be attentive, responsive, and empathetic to guests' needs and requests. By delivering a personalized experience, you can increase guest satisfaction and loyalty, reducing the likelihood of cancellations.
#
# 5. **Loyalty Programs and Incentives**: Implement a loyalty program that rewards repeat bookings. Offer perks such as room upgrades, discounted rates, or exclusive benefits to incentivize guests to choose your hotel again in the future. Loyalty programs can foster a sense of loyalty and encourage guests to think twice before canceling their reservation.
#
# 6.   **Optimize Online Presence**: Ensure that your hotel's online presence is strong and appealing. Invest in professional photography, descriptive and accurate room descriptions, and positive guest reviews. A visually appealing and well-represented online presence can attract more informed and committed guests who are less likely to cancel.
#
#
# 7.   **Overbooking and Waitlists**: Consider implementing an overbooking strategy and managing a waitlist for high-demand periods. However, exercise caution and ensure that overbooking does not lead to guest dissatisfaction or disputes. Effective management of overbooking and waitlists can help fill cancellations with minimal revenue loss.

# %% [markdown]
# Let's check the area from where guests are visiting the hotels and making reservations. Is it coming from Direct or Groups, Online or Offline Travel Agents? Around 46% of the clients come from online travel agencies, whereas 27% come from groups. Only 4% of clients book hotels directly by visiting them and making reservations.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As seen in the graph, reservations are canceled when the average daily rate is higher than when it is not canceled. It clearly proves all the above analysis, that the higher price leads to higher cancellation.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. Cancellation rates rise as the price does. In order to prevent cancellations of reservations, hotels could work on their pricing strategies and try to lower the rates for specific hotels based on locations. They can also provide some
# discounts to the consumers.
#
# 2. As the ratio of the cancellation and not-cancellation of the resort hotel is higher in the resort hotel than the city hotels. So the hotels should provide a reasonable discount on the room prices on weekends or on holidays.
#
# 3. In the month of January, hotels can start campaigns or marketing with a
# reasonable amount to increase their revenue as the cancellation is the highest in this month.
#
# 4. They can also increase the quality of their hotels and their services mainly in Portugal to reduce the cancellation rate.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *   Cancellation rates rise as the price does.
# *   The Ratio of the cancellation and not-cancellation of the resort hotel is higher in the resort hotel than the city hotels.
# * January sees the highest cancellation rates.
# * August sees the least amount of cancellation.
# * Most of the people book their reservation through Online Agents.
# * The country with the highest cancellation rate is Portugal.
# * Cancellation increases as ADR increases and vice-versa.
# * Better discounts and stricter cancellation policies could help increase the number of clients, better profits as well as reduction in cancellation rate.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
